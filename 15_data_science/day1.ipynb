# %% [markdown]
# # Welcoe to Python notebook
#
# ## Day 1
#
# This is wbere you can write your notes

# %%
print("test")
print("blablabl")
# Out:
# test
# blablabl

# %%
for i in range(5):
    print(f"value is {i}")
# Out:
# value is 0
# value is 1
# value is 2
# value is 3
# value is 4
